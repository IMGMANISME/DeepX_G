# %%
# !pip install ultralytics
from ultralytics import YOLO
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.6/78.2 GB disk)

# %% [markdown]
# ##連結google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/DeepX_G/yolov8_custom') #切換目錄
os.listdir() #確認目錄內容
# Out:
# ['YOLOv8',
#  'predict_test.png',
#  'train',
#  'val',
#  'yolov8m.pt',
#  'yolov8n.pt',
#  '指令.txt',
#  'runs',
#  'classes.txt',
#  'data_custom.yaml',
#  'best.pt',
#  'result',
#  '.DS_Store',
#  'train.ipynb']

# %% [markdown]
# ## 訓練(train)與驗證(predict)Yolo模型

# %%
# !yolo task=detect mode=train epochs=200 data=data_custom.yaml model=best.pt imgsz=640 batch=30 patience=100
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#!yolo task=detect mode=predict save=True model=best.pt conf=0.5 source=predict_test.png

# %%
# !yolo task=detect mode=predict save=True model=best.pt conf=0.3 source=/content/drive/MyDrive/DeepX_G/yolov8_custom/result/source save_txt=True
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_-1.png: 640x416 1 wanted, 29.2ms
# image 2/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_-2.png: 640x416 1 wanted, 28.1ms
# image 3/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_-3.png: 640x416 1 wanted, 28.1ms
# image 4/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_-4.png: 640x416 1 wanted, 28.1ms
# image 5/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_0.png: 640x416 1 wanted, 28.2ms
# image 6/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_1.png: 640x416 1 wanted, 28.2ms
# image 7/480 /content/drive/MyDrive/DeepX_G/yolov8_custom/result/source/Bad_1,1,1,1_2.png: 640x416 1 wanted, 28.2ms
# ...
