# %% [markdown]
# ##連結google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/yolov8_custom') #切換目錄
os.listdir() #確認目錄內容
# Out:
# ['.DS_Store',
#  'YOLOv8',
#  'result',
#  'runs',
#  'train',
#  'val',
#  'yolov8m.pt',
#  '指令.txt',
#  'simple_images',
#  'classes.txt',
#  'data_custom.yaml',
#  'best.pt',
#  'test.png',
#  'train.ipynb']

# %% [markdown]
# #建立資料結構
# ```
# ├── YOLOv8
# │   └── yolov8m
# │       └── args.yaml
# ├── classes.txt
# ├── data_custom.yaml
# ├── result
# │   └── source
# ├── runs
# │   └── detect
# ├── simple_images
# ├── test.png
# ├── train
# │   ├── images
# │   └──labels
# ├── train.ipynb
# ├── val
# │   ├── images
# │   └──labels
# └──yolov8m.pt
# ```

# %% [markdown]
# #下載函式庫

# %%
#!pip install simple_image_download

# %%
# !pip install ultralytics
from ultralytics import YOLO
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %% [markdown]
# #訓練(train)與驗證(predict)Yolo模型

# %%
# !yolo task=detect mode=train epochs=200 data=data_custom.yaml model=yolov8m.pt imgsz=640 batch=30 patience=100
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict save=True model=best.pt conf=0.1 source=test.jpeg save_txt=True
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/yolov8_custom/test.jpeg: 384x640 1 dog, 1 cat, 1629.9ms
# Speed: 2.8ms preprocess, 1629.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels

# %%
# !yolo task=detect mode=predict save=True model=best.pt conf=0.3 source=/content/drive/MyDrive/yolov8_custom/result/source save_txt=True
